# %% [markdown]
# <a href="https://colab.research.google.com/github/Devesh15055/APS-LAB/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
import matplotlib.pyplot as plt

# Function to check even or odd
def even_odd(n):
    if n % 2 == 0:
        return "Even"
    else:
        return "Odd"

# Input sizes
n_values = list(range(1, 101))
time_values = []

# Simulate time complexity
for n in n_values:
    even_odd(n)
    time_values.append(1)  # constant time

# Plot
plt.figure()
plt.plot(n_values, time_values, label="O(1)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.legend()
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)
import matplotlib.pyplot as plt

# Function to count even/odd numbers greater than zero
def even_odd_counts(arr):
    even_count, odd_count = 0, 0
    for num in arr:  # loop runs n times
        if num > 0:
            if num % 2 == 0:
                even_count += 1
            else:
                odd_count += 1
    return even_count, odd_count

# Input sizes
n_values = list(range(1, 101))
time_values = []

# Simulate time complexity
for n in n_values:
    arr = list(range(-n, n))  # array of size 2n
    even_odd_counts(arr)
    time_values.append(n)  # linear growth

# Plot
plt.figure()
plt.plot(n_values, time_values, label="O(n)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for Even/Odd Count")
plt.legend()
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import matplotlib.pyplot as plt
import numpy as np   # ✅ Import NumPy

# Binary search function
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

# Input sizes
n_values = list(range(1, 101))
time_values = []

# Simulate time complexity
for n in n_values:
    arr = list(range(n))  # sorted array of size n
    binary_search(arr, n-1)  # search for last element
    time_values.append(np.log2(n))  # logarithmic growth

# Plot
plt.figure()
plt.plot(n_values, time_values, label="O(log n)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(log n) Logarithmic Time Complexity for Binary Search")
plt.legend()
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import matplotlib.pyplot as plt
import numpy as np

# Merge Sort implementation
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Input sizes
n_values = list(range(1, 101))
time_values = []

# Simulate time complexity
for n in n_values:
    arr = list(range(n, 0, -1))  # reverse sorted array
    merge_sort(arr)
    time_values.append(n * np.log2(n))  # n log n growth

# Plot
plt.figure()
plt.plot(n_values, time_values, label="O(n log n)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n log n) Log-Linear Time Complexity for Merge Sort")
plt.legend()
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt
import numpy as np

# Function with O(n^2) complexity (nested loops)
def pairwise_comparison(arr):
    count = 0
    for i in range(len(arr)):
        for j in range(len(arr)):
            if arr[i] < arr[j]:
                count += 1
    return count

# Input sizes
n_values = list(range(1, 51))  # keep smaller for quadratic growth
time_values = []

# Simulate time complexity
for n in n_values:
    arr = list(range(n))
    pairwise_comparison(arr)
    time_values.append(n**2)  # polynomial growth with c=2

# Plot
plt.figure()
plt.plot(n_values, time_values, label="O(n^2)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n^2) Polynomial Time Complexity Example")
plt.legend()
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt
import numpy as np

# Exponential time example: naive recursive Fibonacci
def fib(n):
    if n <= 1:
        return n
    return fib(n-1) + fib(n-2)

# Input sizes
n_values = list(range(1, 21))  # keep small, exponential grows fast
time_values = []

# Simulate time complexity
for n in n_values:
    fib(n)  # compute Fibonacci
    time_values.append(2**n)  # exponential growth

# Plot
plt.figure()
plt.plot(n_values, time_values, label="O(2^n)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(2^n) Exponential Time Complexity for Fibonacci")
plt.legend()
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
# Import required packages
import matplotlib.pyplot as plt
import numpy as np

# Input sizes
n_values = np.arange(1, 21)   # keep small for exponential visibility

# Growth functions
O1 = np.ones_like(n_values)
Ologn = np.log2(n_values)
On = n_values
Onlogn = n_values * np.log2(n_values)
On2 = n_values**2
O2n = 2**n_values

# Plot
plt.figure(figsize=(10,6))
plt.plot(n_values, O1, label="O(1)")
plt.plot(n_values, Ologn, label="O(log n)")
plt.plot(n_values, On, label="O(n)")
plt.plot(n_values, Onlogn, label="O(n log n)")
plt.plot(n_values, On2, label="O(n²)")
plt.plot(n_values, O2n, label="O(2^n)")

plt.xlabel("Input size n")
plt.ylabel("Time (relative)")
plt.title("Growth of Functions in Time Complexity")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)
import matplotlib.pyplot as plt
import numpy as np

# Quick Sort implementation
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]  # choose middle element as pivot
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# Input sizes
n_values = list(range(1, 101))
time_values = []

# Simulate time complexity
for n in n_values:
    arr = list(range(n, 0, -1))  # reverse sorted array
    quick_sort(arr)
    time_values.append(n * np.log2(n))  # O(n log n) growth

# Plot
plt.figure(figsize=(10,6))
plt.plot(n_values, time_values, label="O(n log n)")
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("Quick Sort Average Case Time Complexity: O(n log n)")
plt.legend()
plt.grid(True)
plt.show()
